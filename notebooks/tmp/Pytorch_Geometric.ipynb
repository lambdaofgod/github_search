# %%
from github_search import pytorch_geometric_data
import pandas as pd

# %%
featurizer =

# %%
pytorch_geometric_data.PygGraphWrapper()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 pytorch_geometric_data.PygGraphWrapper()
#
# TypeError: __init__() missing 2 required positional arguments: 'featurizer' and 'records_df'

# %%
class SentenceBERTVectorizer:
    
    def __init__(self, sentence_transformer):
        self.sentence_transformer = sentence_transformer
        
    def transform(X, **kwargs):
        return self.sentence_transformer.encode(X, **kwargs)

# %%
pytorch_geometric_data.PygGraphWrapper()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 pytorch_geometric_data.PygGraphWrapper()
#
# TypeError: __init__() missing 2 required positional arguments: 'featurizer' and 'records_df'

# %%
dependency_records = pd.read_csv("../../output/processed_dependency_records.csv")

# %%
functions_df = pd.read_csv("../../output/python_functions.csv", nrows=10000)

# %%
functions_df
# Out:
#       Unnamed: 0          repo_name  \
# 0              0    trangvu/ape-npi
# 1              1    trangvu/ape-npi
# 2              2    trangvu/ape-npi
# 3              3    trangvu/ape-npi
# 4              4    trangvu/ape-npi
# ...          ...                ...
# 9995        9995  tensorflow/models
# 9996        9996  tensorflow/models
# 9997        9997  tensorflow/models
# 9998        9998  tensorflow/models
# 9999        9999  tensorflow/models
#
#                                                    path    function_name  \
# 0                                          run-tests.py          failure
# 1                                          run-tests.py          success
# 2                                          run-tests.py   get_best_score
# 3                                          run-tests.py              run
# 4                             translate/import_graph.py      ImportGraph
# ...                                                 ...              ...
# ...

# %%
def get_paths(function, dependency_records_df):
    pass

# %%
function = "cifar_transform"

# %%
dependency_records[dependency_records['destination'] == function]
# Out:
#                                                      source      destination  \
# 1205952                   Nithin-Holla/MetaWSD:seq_baseline  cifar_transform
# 1206069                        NivNayman/XNAS:test_imagenet  cifar_transform
# 1206186   NixGD/variational-continual-learning:discrimin...  cifar_transform
# 1206303                   NoaCahan/WavenetAutoEncoder:train  cifar_transform
# 2003316   davidhalladay/MMDetection:cascade_rcnn_dconv_c...  cifar_transform
# 2003372   davidhalladay/MMDetection:ms_rcnn_x101_64x4d_f...  cifar_transform
# 2003428   davidhalladay/MMDetection:ga_retinanet_x101_32...  cifar_transform
# 2003484   davidhalladay/MMDetection:retinanet_ghm_r50_fp...  cifar_transform
# 2172401   facebookresearch/TransCoder:COUNT_DISTINCT_NON...  cifar_transform
# 3508390         signetlabdei/ns3-mmwave-iab:examples-to-run  cifar_transform
# 3732370                           trx14/TrojanNet:trojannet  cifar_transform
# ...
