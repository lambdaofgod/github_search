# %%
#default_exp python_tokens

# %%
#export
import fasttext
import pandas as pd
import tokenize
import io
import keyword
import gensim

# %%
# %cd ..
# Out:
# /home/kuba/Projects/github_search

# %%
python_files_df = pd.read_csv('data/python_files.csv')

# %%
python_files_df.shape
# Out:
# (560183, 5)

# %%
python_files_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560183 entries, 0 to 560182
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   owner      560183 non-null  object
#  1   repo_name  560183 non-null  object
#  2   file_path  560183 non-null  object
#  3   content    546484 non-null  object
#  4   sha        560183 non-null  object
# dtypes: object(5)
# memory usage: 21.4+ MB

# %%
file_text = python_files_df.content[0]

# %%
s = 'abc_'

# %%
s.strip('_')
# Out:
# 'abc'

# %%
#export
PYTHON_KEYWORDS = set(keyword.kwlist)


def prepare_token(token, lowercase):
    prepared_token = token.strip('_')
    if lowercase:
        prepared_token = prepared_token.lower()
    return prepared_token


def get_file_variable_token_set(file_text, min_token_length=2, lowercase=True):
    token_infos = list(tokenize.generate_tokens(io.StringIO(file_text).readline))
    raw_tokens = [t.string for t in token_infos if t.type == 1]
    tokens = (
        prepare_token(t, lowercase) for t in raw_tokens
        if len(prepare_token(t, lowercase)) > min_token_length and not t in PYTHON_KEYWORDS
    )
    return set(tokens)


def maybe_get_file_variable_token_string(file_text, min_token_length=2):
    try:
        tokens = get_file_variable_token_set(file_text)
    except:
        return None
    return ' '.join(tokens)

# %%
tokens = get_file_variable_token_set(python_files_df.content[0])

# %%
' '.join(set(tokens))
# Out:
# 'stdout write len scores score parser shlex listdir basename parse_args join format argparse append min message failure dir gpu_id isdir type fail subprocess nargs print max add_argument okgreen no_gpu get_best_score endc group decode name str extra_params log_file remove line calledprocesserror check_output dirs action stderr int path open split search config_file filenotfounderror float argumentparser args strip run output success'

# %%
fasttext_gensim_filename =  'data/wiki-news-300d-1M.vec'
fasttext_filename = 'data/cc.en.300.bin'

# %%
# %%time
fasttext_model = fasttext.load_model(fasttext_filename)
# Out:
# CPU times: user 1.49 s, sys: 1.48 s, total: 2.96 s
# Wall time: 2.96 s
# ...

# %%
# %%time
fasttext_gensim_model = gensim.models.FastText.load_fasttext_format(fasttext_filename)
# Out:
# <timed exec>:1: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
# CPU times: user 37.2 s, sys: 4.05 s, total: 41.2 s
# Wall time: 41.2 s

# %%
fasttext_model.get_subwords('base_name')
# Out:
# (['<base', 'base_', 'ase_n', 'se_na', 'e_nam', '_name', 'name>'],
#  array([3601990, 3142405, 2240913, 3154387, 2909247, 3169229, 2929672]))

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mlutil.feature_extraction import embeddings

# %%
kv = embeddings.load_gensim_embedding_model('glove-twitter-50')

# %%
kv.wv.vocab
# Out:
# <ipython-input-20-7b8e27b593d4>:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   kv.wv.vocab
# {'<user>': <gensim.models.keyedvectors.Vocab at 0x7f851e9d52b0>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7f851e9d5310>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x7f851e9d5340>,
#  'rt': <gensim.models.keyedvectors.Vocab at 0x7f851e9d5370>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7f851e9d53a0>,
#  '<repeat>': <gensim.models.keyedvectors.Vocab at 0x7f851e9d53d0>,
#  '<hashtag>': <gensim.models.keyedvectors.Vocab at 0x7f851e9d5400>,
#  '<number>': <gensim.models.keyedvectors.Vocab at 0x7f851e9d5430>,
#  '<url>': <gensim.models.keyedvectors.Vocab at 0x7f851e9d5460>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x7f851e9d5490>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f851e9d54c0>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f851e9d54f0>,
#  '"': <gensim.models.keyedvectors.Vocab at 0x7f851e9d5520>,
# ...

# %%
fasttext_gensim_model.wv.vocab
# Out:
# {',': <gensim.models.keyedvectors.Vocab at 0x7f843d36beb0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f843d36be50>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7f843d36bee0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f843d36bf40>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f843d36bfa0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e040>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e0a0>,
#  '</s>': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e100>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e160>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e1c0>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e220>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e280>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e2e0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e340>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x7f8260b7e3a0>,
# ...

# %%
emb_model = embeddings.AverageWordEmbeddingsVectorizer(fasttext_gensim_model)

# %%
fasttext_model.get_subwords('base name')
# Out:
# (['<base', 'base ', 'ase n', 'se na', 'e nam', ' name', 'name>'],
#  array([3601990, 2046056, 3827154, 3993574, 2708980, 3665660, 2929672]))

# %%
fasttext_gensim_model.wv.similarity('base name', 'base_name')
# Out:
# 0.3374281

# %%
from sklearn import metrics

metrics.pairwise.cosine_similarity([(fasttext_model['base_'] + fasttext_model['_name'])], [fasttext_model['base_name']])
# Out:
# array([[0.65326834]], dtype=float32)

# %%
metrics.pairwise.cosine_similarity([(fasttext_model['file_'] + fasttext_model['_name'])], [fasttext_model['file_name']])
# Out:
# array([[0.6577994]], dtype=float32)

# %%
metrics.pairwise.cosine_similarity([(fasttext_model['file'] + fasttext_model['name'])], [fasttext_model['filename']])
# Out:
# array([[0.65270483]], dtype=float32)

# %%
metrics.pairwise.cosine_similarity([fasttext_model['file name']], [fasttext_model['filename']])
# Out:
# array([[0.15743831]], dtype=float32)

# %%
fasttext_model.get_subwords('<base_')
# Out:
# (['<<bas', '<base', 'base_', 'ase_>'],
#  array([3560493, 3601990, 3142405, 2915201]))

# %%
metrics.pairwise.cosine_similarity([(fasttext_model['base name'])], [fasttext_model['base_name']])
# Out:
# array([[0.33742806]], dtype=float32)

# %%
fasttext_gensim_model['gpu_id']
# Out:
# <ipython-input-32-0060d9b150d4>:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   fasttext_gensim_model['gpu_id']
# array([-4.89002280e-03, -5.09326421e-02, -6.47825655e-04,  1.68999881e-02,
#         2.91821212e-02, -7.94018656e-02, -1.58723239e-02, -1.39547074e-02,
#         3.30954827e-02, -3.94083597e-02,  6.53056502e-02,  1.74441896e-02,
#         2.21977122e-02,  1.83864720e-02, -5.92345037e-02, -2.61607878e-02,
#         1.42199378e-02, -1.59157179e-02, -2.17598081e-02,  2.42450852e-02,
#         1.18860025e-02,  1.47764860e-02,  1.41005274e-02,  1.46108773e-03,
#         6.47664741e-02,  3.70978331e-03, -5.28232493e-02, -7.49736279e-03,
#         4.34475690e-02,  8.76194388e-02,  3.18839122e-03, -9.15196026e-04,
#         2.14361511e-02,  1.03679765e-02,  2.98034940e-02, -1.99553110e-02,
#        -2.31093001e-02,  5.11297323e-02,  7.60219526e-03, -3.07187531e-03,
# ...

# %%
metrics.pairwise.cosine_similarity([fasttext_gensim_model['gpu_'] + fasttext_gensim_model['_id']], [fasttext_gensim_model['gpu_id']])
# Out:
# <ipython-input-33-8fb32c734608>:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   metrics.pairwise.cosine_similarity([fasttext_gensim_model['gpu_'] + fasttext_gensim_model['_id']], [fasttext_gensim_model['gpu_id']])
# array([[0.16885671]], dtype=float32)

# %%
metrics.pairwise.cosine_similarity([fasttext_gensim_model['gpu']], [fasttext_gensim_model['gpu_id']])
# Out:
# <ipython-input-38-76625b2e03c0>:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   metrics.pairwise.cosine_similarity([fasttext_gensim_model['gpu']], [fasttext_gensim_model['gpu_id']])
# array([[0.09236824]], dtype=float32)

# %%
'base_name' in fasttext_model.wv.vocab
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-eceb5f998e63> in <module>
# ----> 1 'base_name' in fasttext_model.wv.vocab
#
# AttributeError: '_FastText' object has no attribute 'wv'

# %%
fasttext_gensim_model.similar_by_word('basename', restrict_vocab=['base_name'])
# Out:
# <ipython-input-37-dd44c18dabd7>:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   fasttext_gensim_model.similar_by_word('basename', restrict_vocab=['base_name'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-dd44c18dabd7> in <module>
# ----> 1 fasttext_gensim_model.similar_by_word('basename', restrict_vocab=['base_name'])
#
# ~/.local/lib/python3.8/site-packages/gensim/utils.py in new_func1(*args, **kwargs)
#    1459                     stacklevel=2
#    1460                 )
# -> 1461                 return func(*args, **kwargs)
#    1462
#    1463             return new_func1
#
# ~/.local/lib/python3.8/site-packages/gensim/models/base_any2vec.py in similar_by_word(self, word, topn, restrict_vocab)
#    1409
#    1410         """
# ...

# %%
fasttext_gensim_model.wv['base_name']

# %%
name_tokens = [t.string for t in tokens if t.type == 1]

# %%
len(name_tokens)

# %%
fasttext_model['dir']

# %%
(fasttext_model['base'] + fasttext_model['name']) / 2

# %%
fasttext_model['basename']

# %%
#export
import re


def tokenize_snakecase(identifier):
    return identifier.split('_')


def tokenize_camelcase(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]


def tokenize_python(identifier):
    if '_' in identifier:
        return tokenize_snakecase(identifier)
    else:
        return tokenize_camelcase(identifier)

# %% [markdown]
# ## Tokenization with snake_case and camelCase

# %%
sample_indices = [440474,  36781, 354010, 178387, 419719, 339569, 152156,  60910,
       222558, 193026, 122137, 124549,  89980, 239861, 414256, 338844,
        10879,  30335,  21236,  97763, 311120,  17600, 287534, 332230,
       506907, 266700, 503993, 550945,  85899, 174301, 556229, 393373,
       293069,  49026, 398339, 249483, 379641,  22215,  36929, 553842,
       424590, 487848, 109245, 388546, 355631,  28722, 278171, 146009,
       547155, 106539,  75253, 384480, 305051, 184188, 492219, 347782,
       394129, 460031, 528396, 196243, 131261, 425323,  83303, 370216,
       343974, 488911,   2747, 507266, 200215,  58190,  60755, 507065,
       427642,  26555,  92877, 134734, 367518, 175535, 169204, 415873,
       384932, 273915,  63875,  82378, 140190, 399600,  78494,  44481,
       479709, 331486,  86315, 306864, 163347, 192107, 313507, 537156,
       390620, 425218, 146966, 460223]

# %%
example_file_contents = python_files_df['content'].iloc[sample_indices]
print(example_file_contents.iloc[1])

# %%
all_tokens = [
    token
    for contents in example_file_contents
    if type(contents) is str
    for token in python_tokens.get_file_variable_token_set(contents, lowercase=False)
]

# %%
snakecase_embeddable_tokens = [t for t in all_tokens if all(token_part in fasttext_gensim_model.wv.vocab for token_part in tokenize_snakecase(t))]
non_snakecase_embeddable_tokens = [t for t in all_tokens if not all(token_part in fasttext_gensim_model.wv.vocab for token_part in tokenize_snakecase(t))]

# %%
len(snakecase_embeddable_tokens) / len(all_tokens)

# %%
embeddable_tokens = [t for t in all_tokens if all(token_part in fasttext_gensim_model.wv.vocab for token_part in tokenize_python(t))]
non_embeddable_tokens = [t for t in all_tokens if not all(token_part in fasttext_gensim_model.wv.vocab for token_part in tokenize_python(t))]

# %%
len(embeddable_tokens) / len(all_tokens)
